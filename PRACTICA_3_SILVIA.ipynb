# %% [markdown]
# <a href="https://colab.research.google.com/github/silviafiorellaym-create/PRACTICA-3/blob/main/PRACTICA_3_SILVIA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import seaborn as sns

# %%
#Carga de archivos desde ruta
#portfolio.json
#profile.json
#transcript.json
ruta_sb_oferta = 'starbucks/portfolio.json'
ruta_sb_cliente = 'starbucks/profile.json'
ruta_sb_transcript = 'starbucks/transcript.json'
